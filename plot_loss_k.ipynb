# %%
private_losses = [0.38494,0.39103,0.39819]
public_losses = [0.26514,0.27034,0.28072]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot([1,2,3], private_losses, 'ro-', label="private_losses",alpha=0.5)
plt.plot([1,2,3], public_losses, 'bo-',label="public_losses", alpha=0.5)
plt.legend(loc="best",fontsize=12)
plt.xlabel("K (Number of GCN layers)",fontsize=12)
plt.ylabel("Loss",fontsize=12)
ticks = plt.xticks([1,2,3],fontsize=12)
ticks = plt.yticks(fontsize=12)

# %%
private_losses = [0.4727,0.41348,0.38571,0.38494,0.38490]
public_losses = [0.3798,0.30424,0.26614,0.26514,0.26401]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot([1,2,3,4,5], private_losses, 'ro-', label="private_losses",alpha=0.5)
plt.plot([1,2,3,4,5], public_losses, 'bo-',label="public_losses", alpha=0.5)
plt.legend(loc="best",fontsize=12)
# plt.xlabel("K (Number of GCN layers)",fontsize=12)
plt.ylabel("Loss",fontsize=12)
ticks = plt.xticks([1,2,3,4,5],fontsize=12)
ticks = plt.yticks(fontsize=12)
