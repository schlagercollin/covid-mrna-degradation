# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import json
#import seaborn as sns
import os

import random
from tqdm.notebook import tqdm
#import plotly.express as px

#import lightgbm as lgb
import copy
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, Dataset, DataLoader, random_split
from torch.nn import functional as F
from torch.optim import lr_scheduler

import RNA

os.getcwd()
# Out:
# '/Users/ishanshah/Documents/covid-mrna-degradation'

# %% [markdown]
# # Settings

# %%
class config:
    train_file = '/home/veer/covid-mrna-degradation/data/train.json'
    test_file = '/home/veer/covid-mrna-degradation/data/test.json'
    pretrain_dir = './'
    sample_submission = '/home/veer/covid-mrna-degradation/data/sample_submission.csv'
    learning_rate = 0.001
    batch_size = 64
    n_epoch = 20
    n_split = 2
    K = 1 # number of aggregation loop (also means number of GCN layers)
    gcn_agg = 'mean' # aggregator function: mean, conv, lstm, pooling
    filter_noise = True
    seed = 1234

# %%
class config:
    train_file = '/Users/ishanshah/Documents/covid-mrna-degradation/data/train.json'
    test_file = '/Users/ishanshah/Documents/covid-mrna-degradation/data/test.json'
    pretrain_dir = './'
    sample_submission = '//Users/ishanshah/Documents/covid-mrna-degradation/data/sample_submission.csv'
    learning_rate = 0.001
    batch_size = 64
    n_epoch = 20
    n_split = 2
    K = 1 # number of aggregation loop (also means number of GCN layers)
    gcn_agg = 'mean' # aggregator function: mean, conv, lstm, pooling
    filter_noise = True
    seed = 1234

# %% [markdown]
# # Utils

# %%
class AverageMeter:
    """
    Computes and stores the average and current value
    """
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
seed_everything(config.seed)

# %% [markdown]
# # Define model

# %%
class GCN(nn.Module):
    '''
    Implementation of one layer of GraphSAGE
    '''
    def __init__(self, input_dim, output_dim, aggregator=config.gcn_agg):
        super(GCN, self).__init__()
        self.aggregator = aggregator
        
        if aggregator == 'mean':
            linear_input_dim = input_dim * 2
        elif aggregator == 'conv':
            linear_input_dim = input_dim
#         elif aggregator == 'pooling':
#             linear_input_dim = input_dim * 2
#             self.linear_pooling = nn.Linear(input_dim, input_dim)
        elif aggregator == 'lstm':
            self.lstm_hidden = 64
            linear_input_dim = input_dim + self.lstm_hidden
            self.lstm_agg = nn.LSTM(input_dim, self.lstm_hidden, num_layers=1, batch_first=True)
        
        self.linear_gcn = nn.Linear(in_features=linear_input_dim, out_features=output_dim)
        
    def forward(self, input_, adj_matrix):
        if self.aggregator == 'conv':
            # set elements in diagonal of adj matrix to 1 with conv aggregator
            idx = torch.arange(0, adj_matrix.shape[-1], out=torch.LongTensor())
            adj_matrix[:, idx, idx] = 1
            
        adj_matrix = adj_matrix.type(torch.float32)
        sum_adj = torch.sum(adj_matrix, axis=2)
        sum_adj[sum_adj==0] = 1
        
        if self.aggregator == 'mean' or self.aggregator == 'conv':
            feature_agg = torch.bmm(adj_matrix, input_)
            feature_agg = feature_agg / sum_adj.unsqueeze(dim=2)
            
#         elif self.aggregator == 'pooling':
#             feature_pooling = self.linear_pooling(input_)
#             feature_agg = torch.sigmoid(feature_pooling)
#             feature_agg = torch.bmm(adj_matrix, feature_agg)
#             feature_agg = feature_agg / sum_adj.unsqueeze(dim=2)

        elif self.aggregator == 'lstm':
            feature_agg = torch.zeros(input_.shape[0], input_.shape[1], self.lstm_hidden).cuda()
            for i in range(adj_matrix.shape[1]):
                neighbors = adj_matrix[:, i, :].unsqueeze(2) * input_
                _, hn = self.lstm_agg(neighbors)
                feature_agg[:, i, :] = torch.squeeze(hn[0], 0)
                
        if self.aggregator != 'conv':
            feature_cat = torch.cat((input_, feature_agg), axis=2)
        else:
            feature_cat = feature_agg
                
        feature = torch.sigmoid(self.linear_gcn(feature_cat))
        feature = feature / torch.norm(feature, p=2, dim=2).unsqueeze(dim=2)
        
        return feature
    
class Net(nn.Module):
    def __init__(self, num_embedding=14, seq_len=107, pred_len=68, dropout=0.5, 
                 embed_dim=100, hidden_dim=128, K=1, aggregator='mean'):
        '''
        K: number of GCN layers
        aggregator: type of aggregator function
        '''
        print("using aggregate function %s"%aggregator)
        super(Net, self).__init__()
        
        self.pred_len = pred_len
        self.embedding_layer = nn.Embedding(num_embeddings=num_embedding, 
                                      embedding_dim=embed_dim)
        
        self.gcn = nn.ModuleList([GCN(3 * embed_dim, 3 * embed_dim, aggregator=aggregator) for i in range(K)])
        
        self.gru_layer = nn.GRU(input_size=3 * embed_dim, 
                          hidden_size=hidden_dim, 
                          num_layers=3, 
                          batch_first=True, 
                          dropout=dropout, 
                          bidirectional=True)
        
        self.linear_layer = nn.Linear(in_features=2 * hidden_dim, 
                                out_features=5)
        
    def forward(self, input_, adj_matrix):
        #embedding
        embedding = self.embedding_layer(input_)
        embedding = torch.reshape(embedding, (-1, embedding.shape[1], embedding.shape[2] * embedding.shape[3]))
        
        #gcn
        gcn_feature = embedding
        for gcn_layer in self.gcn:
            gcn_feature = gcn_layer(gcn_feature, adj_matrix)
        
        #gru
        gru_output, gru_hidden = self.gru_layer(gcn_feature)
        truncated = gru_output[:, :self.pred_len]
        
        output = self.linear_layer(truncated)
        
        return output

# %% [markdown]
# # Load Data

# %%
pred_cols = ['reactivity', 'deg_Mg_pH10', 'deg_pH10', 'deg_Mg_50C', 'deg_50C']

# %%
token2int = {x:i for i, x in enumerate('().ACGUBEHIMSX')}

def get_couples(structure):
    """
    For each closing parenthesis, I find the matching opening one and store their index in the couples list.
    The assigned list is used to keep track of the assigned opening parenthesis
    """
    opened = [idx for idx, i in enumerate(structure) if i == '(']
    closed = [idx for idx, i in enumerate(structure) if i == ')']

    assert len(opened) == len(closed)
    assigned = []
    couples = []

    for close_idx in closed:
        for open_idx in opened:
            if open_idx < close_idx:
                if open_idx not in assigned:
                    candidate = open_idx
            else:
                break
        assigned.append(candidate)
        couples.append([candidate, close_idx])
        
    assert len(couples) == len(opened)
    
    return couples

def build_matrix(couples, size):
    mat = np.zeros((size, size))
    
    for i in range(size):  # neigbouring bases are linked as well
        if i < size - 1:
            mat[i, i + 1] = 1
        if i > 0:
            mat[i, i - 1] = 1
    
    for i, j in couples:
        mat[i, j] = 1
        mat[j, i] = 1
        
    return mat

def convert_to_adj(structure):
    couples = get_couples(structure)
    mat = build_matrix(couples, len(structure))
    return mat

def preprocess_inputs(df, cols=['sequence', 'structure', 'predicted_loop_type']):
    inputs = np.transpose(
        np.array(
            df[cols]
            .applymap(lambda seq: [token2int[x] for x in seq])
            .values
            .tolist()
        ),
        (0, 2, 1)
    )
    
    adj_matrix = np.array(df['structure'].apply(convert_to_adj).values.tolist())
    
    return inputs, adj_matrix

# %%
train = pd.read_json(config.train_file, lines=True)

if config.filter_noise:
    train = train[train.signal_to_noise > 1]
    
test = pd.read_json(config.test_file, lines=True)
sample_df = pd.read_csv(config.sample_submission)

# %%
seqs = list(train['sequence'])
seqs[0]
# Out:
# 'GGAAAAGCUCUAAUAACAGGAGACUAGGACUACGUAUUUCUAGGUAACUGGAAUAACCCAUACCAGCAGUUAGAGUUCGCUCUAACAAAAGAAACAACAACAACAAC'

# %%
def get_predicted_loop_type(sequence, structure, debug=False):
    # !echo $sequence > a.dbn
    # !echo "$structure" >> a.dbn
    # !export PERL5LIB=/root/perl5/lib/perl5 && perl bpRNA/bpRNA.pl a.dbn
    result = [l.strip('\n') for l in open('a.st')]
    if debug:
        print(sequence)
        print(structure)
        print(result[5])
    return result

# %%
train.shape[0]
# Out:
# 2096

# %%
import random
import time
random.seed(12345)
sample_inds = random.sample(list(range(2096)), 250)
sample_inds = np.array(sorted(sample_inds))
train_sample = train.reset_index().iloc[sample_inds, :]

# %%
sample_inds
# Out:
# array([   8,   13,   14,   27,   38,   41,   47,   52,   56,   62,   69,
#          96,  100,  110,  111,  112,  120,  125,  129,  136,  144,  155,
#         164,  165,  167,  170,  180,  187,  202,  206,  209,  232,  241,
#         242,  249,  252,  270,  277,  278,  309,  318,  321,  327,  335,
#         340,  371,  373,  375,  384,  392,  394,  395,  407,  408,  433,
#         440,  449,  454,  465,  486,  488,  490,  492,  497,  508,  513,
#         531,  553,  557,  585,  600,  606,  608,  613,  614,  615,  620,
#         639,  642,  648,  652,  657,  662,  664,  666,  669,  670,  672,
#         675,  682,  713,  714,  720,  728,  729,  732,  735,  738,  744,
#         745,  754,  757,  761,  765,  769,  777,  778,  793,  798,  822,
#         825,  826,  832,  842,  844,  849,  853,  854,  876,  882,  886,
#         899,  901,  909,  938,  944,  951,  952,  955,  988,  989,  996,
#        1019, 1055, 1061, 1064, 1069, 1082, 1085, 1106, 1116, 1126, 1163,
#        1173, 1180, 1197, 1222, 1223, 1229, 1232, 1234, 1255, 1258, 1265,
#        1277, 1282, 1291, 1306, 1307, 1308, 1319, 1326, 1331, 1332, 1334,
#        1349, 1351, 1352, 1353, 1363, 1374, 1390, 1396, 1399, 1400, 1413,
#        1430, 1432, 1448, 1453, 1470, 1490, 1492, 1506, 1508, 1509, 1510,
#        1520, 1522, 1527, 1528, 1536, 1555, 1569, 1581, 1589, 1590, 1591,
#        1595, 1606, 1616, 1625, 1645, 1663, 1679, 1688, 1692, 1697, 1698,
#        1701, 1706, 1710, 1717, 1723, 1734, 1737, 1748, 1773, 1776, 1786,
#        1792, 1800, 1818, 1823, 1825, 1839, 1865, 1873, 1879, 1885, 1886,
#        1887, 1921, 1926, 1931, 1967, 1969, 1985, 1991, 2009, 2014, 2017,
#        2027, 2031, 2044, 2064, 2065, 2069, 2090, 2091])

# %%
int2token = {v:k for k,v in token2int.items()}

# %%
# DO ALL THIS BEFORE THE PERTURBATIONS:
base_pairs = {3:'A', 4:'C', 5:'G', 6:'U'}
train_inputs, train_adj = preprocess_inputs(train_sample)
train_labels = np.array(train[pred_cols].values.tolist()).transpose((0, 2, 1))

num_seqs = train_inputs.shape[0] 
seq_len = train_inputs.shape[1]

train_adj = torch.tensor(train_adj, dtype=torch.float32, requires_grad=False)
train_labels = torch.tensor(train_labels, dtype=torch.float32)

#embedding
embedding_layer = nn.Embedding(num_embeddings=14, 
                                      embedding_dim=100)

results_dict = {}

every_5_bases = [i for i in range(seq_len) if i%5 == 0]

# %%
model_path = "/Users/ishanshah/Documents/covid-mrna-degradation/GCN_GRU/GCN_mean_patience10/gcn_gru_4.pt"
model = Net(seq_len=107, pred_len=107, K=config.K, aggregator=config.gcn_agg)
model.load_state_dict(torch.load(model_path, map_location='cpu'))

# EXECUTE THE PERTURBATIONS
for i in every_5_bases:
    orig_bp = copy.deepcopy(train_inputs[:,i,0])
    orig_struct = copy.deepcopy(train_inputs[:,:,1])
    orig_loop = copy.deepcopy(train_inputs[:,:,2])    
    results_dict[i] = {}
    for base in [3,4,5,6]:
        print("Base = {}; Sequence Position = {}".format(int2token[base], i))
        train_inputs[:,i,0] = base        
        pert_seqs = [''.join(i) for i in np.vectorize(int2token.get)(train_inputs[:,:,0])]
        
        #t = time.time()
        
        pert_secondaries = []
        pert_loop_types = []
        
        iters = 0
        for s in pert_seqs:
            secondary = RNA.fold(s)[0]
            secondary_ints = [token2int[i] for i in list(secondary)]
            pert_secondaries.append(secondary_ints)
            res = get_predicted_loop_type(s, secondary, debug=False)
            loop_type_ints = [token2int[i] for i in list(res[5])]
            pert_loop_types.append(loop_type_ints)
            iters += 1
            
            if iters % 100 == 0:
                print(str(iters) + " sequences done.")
         
        train_inputs[:,:,1] = np.array(pert_secondaries)
        train_inputs[:,:,2] = np.array(pert_loop_types)
    
        #print("Time:", time.time() - t)
        
        # Convert to embedding and get it into training format
        train_inputs_tens = torch.tensor(train_inputs, dtype=torch.long)
        train_inputs_tens = train_inputs_tens.clone().detach().requires_grad_(False)
        
        print("Forward pass starting:")
        model.eval()
        t = time.time()
        preds = model(train_inputs_tens, train_adj)
        preds = preds.cpu().detach().numpy()
        print("Forward pass time:", time.time() - t)
        results_dict[i][base_pairs[base]] = preds
        # DO FORWARD PASS. (forward pass function)
        # results_dict[i][base_pairs[base]] = results list of 5(?)
    train_inputs[:,i,0] = orig_bp
    train_inputs[:,:,1] = orig_struct
    train_inputs[:,:,2] = orig_loop

    #if i == 10:
        #break
# Out:
# using aggregate function mean
# Base = A; Sequence Position = 0
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.4669179916381836
# Base = C; Sequence Position = 0
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.608271837234497
# Base = G; Sequence Position = 0
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.3104510307312012
# Base = U; Sequence Position = 0
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.180577039718628
# Base = A; Sequence Position = 5
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.214777946472168
# Base = C; Sequence Position = 5
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1793489456176758
# Base = G; Sequence Position = 5
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.197394847869873
# Base = U; Sequence Position = 5
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2127189636230469
# Base = A; Sequence Position = 10
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1568999290466309
# Base = C; Sequence Position = 10
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1622569561004639
# Base = G; Sequence Position = 10
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.164247989654541
# Base = U; Sequence Position = 10
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.3889989852905273
# Base = A; Sequence Position = 15
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2339539527893066
# Base = C; Sequence Position = 15
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2833900451660156
# Base = G; Sequence Position = 15
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.187892198562622
# Base = U; Sequence Position = 15
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1768798828125
# Base = A; Sequence Position = 20
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.6700150966644287
# Base = C; Sequence Position = 20
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.389591932296753
# Base = G; Sequence Position = 20
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.6017138957977295
# Base = U; Sequence Position = 20
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2589690685272217
# Base = A; Sequence Position = 25
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.160858154296875
# Base = C; Sequence Position = 25
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1613059043884277
# Base = G; Sequence Position = 25
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1580030918121338
# Base = U; Sequence Position = 25
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1782069206237793
# Base = A; Sequence Position = 30
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.4544870853424072
# Base = C; Sequence Position = 30
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1767299175262451
# Base = G; Sequence Position = 30
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2358379364013672
# Base = U; Sequence Position = 30
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.471437931060791
# Base = A; Sequence Position = 35
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.3272521495819092
# Base = C; Sequence Position = 35
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2170610427856445
# Base = G; Sequence Position = 35
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.255190134048462
# Base = U; Sequence Position = 35
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2124180793762207
# Base = A; Sequence Position = 40
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2899799346923828
# Base = C; Sequence Position = 40
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1746809482574463
# Base = G; Sequence Position = 40
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.207360029220581
# Base = U; Sequence Position = 40
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1842670440673828
# Base = A; Sequence Position = 45
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.3418498039245605
# Base = C; Sequence Position = 45
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.301900863647461
# Base = G; Sequence Position = 45
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2746610641479492
# Base = U; Sequence Position = 45
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2346370220184326
# Base = A; Sequence Position = 50
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.537883996963501
# Base = C; Sequence Position = 50
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2573151588439941
# Base = G; Sequence Position = 50
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.4270009994506836
# Base = U; Sequence Position = 50
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2937278747558594
# Base = A; Sequence Position = 55
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2952220439910889
# Base = C; Sequence Position = 55
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.3923940658569336
# Base = G; Sequence Position = 55
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1972999572753906
# Base = U; Sequence Position = 55
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.4050989151000977
# Base = A; Sequence Position = 60
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.221951961517334
# Base = C; Sequence Position = 60
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2271900177001953
# Base = G; Sequence Position = 60
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.6484410762786865
# Base = U; Sequence Position = 60
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.6739299297332764
# Base = A; Sequence Position = 65
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1665980815887451
# Base = C; Sequence Position = 65
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.201819896697998
# Base = G; Sequence Position = 65
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.16920804977417
# Base = U; Sequence Position = 65
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1711311340332031
# Base = A; Sequence Position = 70
# Use of uninitialized value $maxI in delete at bpRNA/bpRNA.pl line 1029.
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.29557204246521
# Base = C; Sequence Position = 70
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1593759059906006
# Base = G; Sequence Position = 70
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.5080969333648682
# Base = U; Sequence Position = 70
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1618812084197998
# Base = A; Sequence Position = 75
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.166515827178955
# Base = C; Sequence Position = 75
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1759600639343262
# Base = G; Sequence Position = 75
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1297581195831299
# Base = U; Sequence Position = 75
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2026910781860352
# Base = A; Sequence Position = 80
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1879870891571045
# Base = C; Sequence Position = 80
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1824660301208496
# Base = G; Sequence Position = 80
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.629241943359375
# Base = U; Sequence Position = 80
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.8261339664459229
# Base = A; Sequence Position = 85
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.233515977859497
# Base = C; Sequence Position = 85
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.5010790824890137
# Base = G; Sequence Position = 85
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.3658530712127686
# Base = U; Sequence Position = 85
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.4068090915679932
# Base = A; Sequence Position = 90
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2714428901672363
# Base = C; Sequence Position = 90
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2837920188903809
# Base = G; Sequence Position = 90
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.4287350177764893
# Base = U; Sequence Position = 90
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2100639343261719
# Base = A; Sequence Position = 95
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1873509883880615
# Base = C; Sequence Position = 95
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1633930206298828
# Base = G; Sequence Position = 95
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.168652057647705
# Base = U; Sequence Position = 95
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1814780235290527
# Base = A; Sequence Position = 100
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1801371574401855
# Base = C; Sequence Position = 100
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.1635828018188477
# Base = G; Sequence Position = 100
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.185502052307129
# Base = U; Sequence Position = 100
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.2785060405731201
# Base = A; Sequence Position = 105
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.264286994934082
# Base = C; Sequence Position = 105
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.236212968826294
# Base = G; Sequence Position = 105
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.7406680583953857
# Base = U; Sequence Position = 105
# 100 sequences done.
# 200 sequences done.
# Forward pass starting:
# Forward pass time: 1.4677448272705078

# %%
results_dict
# Out:
# {0: {'A': array([[[ 4.16235149e-01,  4.04615372e-01,  2.25840116e+00,
#             3.45499784e-01,  6.18701637e-01],
#           [ 1.00560939e+00,  1.34839296e+00,  2.50353956e+00,
#             1.20522416e+00,  1.34742177e+00],
#           [ 1.01923370e+00,  6.52383268e-01,  9.87840891e-01,
#             9.63504970e-01,  1.19522607e+00],
#           ...,
#           [ 3.22969317e-01,  1.26213253e-01, -3.94907296e-02,
#             1.21013202e-01,  2.46659160e-01],
#           [ 5.85028380e-02,  3.68151441e-02, -2.86091268e-01,
#             6.52546063e-02, -2.38685347e-02],
#           [-1.24186665e-01, -1.55611128e-01, -7.05619454e-01,
#            -1.82703584e-01, -3.11620831e-01]],
#
#          [[ 5.42197466e-01,  6.72395706e-01,  1.81090796e+00,
#             6.68633461e-01,  7.28606880e-01],
#           [ 1.45411956e+00,  2.72437358e+00,  3.03472686e+00,
#             2.60136342e+00,  2.04585624e+00],
#           [ 1.34276831e+00,  1.13310611e+00,  1.15244889e+00,
#             1.52869928e+00,  1.29798162e+00],
#           ...,
#           [ 3.11314166e-01,  1.48904771e-01, -3.97956371e-03,
#             1.67142749e-01,  2.86873162e-01],
#           [ 5.14775068e-02,  5.26105240e-02, -2.59584129e-01,
#             1.04912400e-01,  1.07785724e-02],
#           [ 4.36056405e-02,  3.72178480e-02, -2.47692317e-01,
#             6.82129636e-02,  3.24617699e-03],
#           [-1.26607522e-01, -1.54615760e-01, -6.58694267e-01,
#            -1.65410578e-01, -2.78480470e-01]]], dtype=float32)},
#  5: {'A': array([[[ 0.45215112,  0.4081562 ,  2.1609237 ,  0.40594503,
#             0.65870357],
#           [ 1.4151694 ,  2.0036411 ,  3.358168  ,  1.9140452 ,
#             2.00647   ],
#           [ 1.2017516 ,  0.96110326,  1.1589811 ,  1.3725243 ,
#             1.4246923 ],
#           ...,
#           [ 0.31430113,  0.12164407, -0.02999711,  0.1253681 ,
#             0.2569994 ],
#           [ 0.0533541 ,  0.03176431, -0.28005508,  0.06783018,
#            -0.01611642],
#           [-0.12966499, -0.1609551 , -0.7016554 , -0.18111226,
#            -0.30592287]],
#
#          [[ 0.6151123 ,  0.59407467,  1.8474468 ,  0.5996562 ,
#             0.7551848 ],
#           [ 1.7014287 ,  2.9683561 ,  3.6236522 ,  2.7855604 ,
#             2.276911  ],
#           [ 1.4571887 ,  1.1624693 ,  1.1756325 ,  1.4765652 ,
#             1.2567583 ],
#           ...,
#           [ 0.3093863 ,  0.1440452 , -0.0076942 ,  0.16049695,
#             0.28409874],
#           [ 0.04928495,  0.04864489, -0.26269677,  0.09894784,
#             0.008075  ],
#           [-0.1410716 , -0.14131638, -0.68152463, -0.1527941 ,
#            -0.28033042]],
#
#          [[ 0.5272473 ,  0.50145453,  1.5655509 ,  0.5394225 ,
#             0.73762137],
#           [ 1.522075  ,  2.4429212 ,  2.952737  ,  2.6047704 ,
#             2.173875  ],
#           [ 1.1235857 ,  0.3862255 ,  0.48140284,  0.46291065,
#             0.5912909 ],
#           ...,
#           [ 0.29926562,  0.15331337,  0.04005127,  0.18990576,
#             0.31117374],
#           [ 0.04673041,  0.05150843, -0.22836784,  0.121533  ,
#             0.02823474],
#           [-0.14930749, -0.13407692, -0.64085126, -0.12561053,
#            -0.25559157]],
#
#          ...,
#
#          [[ 0.541091  ,  0.48084405,  1.4985347 ,  0.52500737,
#             0.7032555 ],
#           [ 1.5978528 ,  2.1801572 ,  2.593415  ,  2.224071  ,
#             1.8843879 ],
#           [ 1.2935982 ,  0.99598235,  1.0285091 ,  1.3572682 ,
#             1.1644753 ],
#           ...,
#           [ 0.28124362,  0.12783065,  0.0095543 ,  0.16107425,
#             0.29920495],
#           [ 0.03898267,  0.02784453, -0.25202015,  0.09642394,
#             0.02162552],
#           [-0.14788067, -0.16258919, -0.6766192 , -0.15811363,
#            -0.27111042]],
#
#          [[ 0.60283303,  0.5460046 ,  1.802838  ,  0.5873786 ,
#             0.77924484],
#           [ 2.074879  ,  3.134388  ,  4.0890813 ,  3.3281357 ,
#             2.727236  ],
#           [ 1.2742093 ,  0.2758713 ,  0.3752524 ,  0.31062183,
#             0.50404054],
#           ...,
#           [ 0.28330082,  0.12470338,  0.04587333,  0.14482778,
#             0.29902455],
#           [ 0.04028566,  0.02120641, -0.22652766,  0.07719873,
#             0.01554618],
#             1.74153656e-01,  3.11874270e-01],
#           [ 4.23748046e-02,  2.75727361e-02, -2.42460042e-01,
#             1.08106092e-01,  3.29436623e-02],
#           [-1.44798234e-01, -1.61067545e-01, -6.64787889e-01,
#            -1.44979715e-01, -2.58242220e-01]],
#
#          [[ 6.02833033e-01,  5.46004593e-01,  1.80283797e+00,
#             5.87378621e-01,  7.79244840e-01],
#           [ 2.07487893e+00,  3.13438797e+00,  4.08908129e+00,
#             3.32813573e+00,  2.72723603e+00],
#           [ 1.27420926e+00,  2.75871307e-01,  3.75252396e-01,
#             3.10621828e-01,  5.04040539e-01],
#           ...,
#           [ 2.83300817e-01,  1.24703385e-01,  4.58733290e-02,
#             1.44827783e-01,  2.99024552e-01],
#           [ 4.02856618e-02,  2.12064050e-02, -2.26527661e-01,
#             7.71987289e-02,  1.55461766e-02],
#           [-1.55629352e-01, -1.68395817e-01, -6.52783990e-01,
#            -1.77833378e-01, -2.77470887e-01]],
#
#          [[ 1.75862357e-01,  2.88108200e-01,  2.67181754e+00,
#             1.35386199e-01,  5.13222516e-01],
#           [ 7.53710032e-01,  6.75625384e-01,  2.05510449e+00,
#             6.09274209e-01,  1.02143705e+00],
#           [ 4.87214267e-01,  1.55068636e-01,  5.89939356e-01,
#             2.48739690e-01,  5.42093217e-01],
#           ...,
#           [ 2.99082935e-01,  1.20498113e-01,  3.43009830e-04,
#             1.20301776e-01,  2.73575515e-01],
#           [ 4.41111773e-02,  3.68298888e-02, -2.48218685e-01,
#             6.55014664e-02,  1.49865821e-03],
#           [-1.25918031e-01, -1.55129761e-01, -6.59341574e-01,
#            -1.68171614e-01, -2.80230224e-01]]], dtype=float32),
#   'C': array([[[ 0.40800202,  0.38610598,  2.2637599 ,  0.328136  ,
#             0.6022555 ],
#           [ 0.9939322 ,  1.3419363 ,  2.5322158 ,  1.1908222 ,
#             1.3471628 ],
#           [ 1.0080549 ,  0.6407495 ,  0.9726368 ,  0.95501864,
#             1.1973988 ],
#           ...,
#           [ 0.22174619,  0.09449597, -0.05312249,  0.06958637,
#             0.03557576],
#           [-0.07346044, -0.10641119, -0.43549904, -0.10460938,
#            -0.2523937 ],
#           [-0.13854063, -0.22087494, -0.83526075, -0.2999752 ,
#            -0.4222104 ]],
#
#          [[ 0.54299843,  0.66929704,  1.8007582 ,  0.66752875,
#             0.72275287],
#           [ 1.4550787 ,  2.7280436 ,  3.0300472 ,  2.610201  ,
#             2.0447378 ],
#           [ 1.3443587 ,  1.1333762 ,  1.1464852 ,  1.5319597 ,
#             1.2942008 ],
#           ...,
#           [ 0.21057622,  0.10675474, -0.00891146,  0.11251124,
#             0.07662138],
#           [-0.08478162, -0.0979624 , -0.3971674 , -0.07033525,
#            -0.21731013],
#           [-0.15708344, -0.21178365, -0.80263436, -0.27107102,
#            -0.3926906 ]],
#
#          [[ 0.4747718 ,  0.44566053,  1.5459849 ,  0.43312424,
#             0.6060361 ],
#           [ 1.058287  ,  1.1976676 ,  1.8653334 ,  1.1683916 ,
#             1.1612369 ],
#           [ 1.0965339 ,  0.8820543 ,  0.9940516 ,  1.1611497 ,
#             1.0981425 ],
#           ...,
#           [ 0.21722488,  0.11144982,  0.0330344 ,  0.1366438 ,
#             0.09822868],
#           [-0.07988043, -0.09751414, -0.36503372, -0.05141331,
#            -0.20163308],
#           [-0.15342179, -0.21001926, -0.76598334, -0.2517943 ,
#            -0.37293094]],
#
#          ...,
#
#          [[ 0.57991254,  0.67020804,  1.6192534 ,  0.6263437 ,
#             0.67375106],
#           [ 1.450365  ,  1.8189154 ,  2.131931  ,  1.6721257 ,
#             1.343469  ],
#           [ 1.3254158 ,  1.1950042 ,  1.3808042 ,  1.5376006 ,
#             1.509678  ],
#           ...,
#           [ 0.19434781,  0.09241871,  0.01853794,  0.12369862,
#             0.10026731],
#           [-0.08094044, -0.11370205, -0.37794837, -0.0592415 ,
#            -0.19762534],
#           [-0.16258274, -0.23203504, -0.79044855, -0.2696156 ,
#            -0.38494384]],
#
#          [[ 0.6020996 ,  0.54330623,  1.793948  ,  0.585875  ,
#             0.7748448 ],
#           [ 2.075163  ,  3.1345634 ,  4.081582  ,  3.328916  ,
#             2.7231677 ],
#           [ 1.2737437 ,  0.27409956,  0.36829177,  0.31030127,
#             0.5013165 ],
#           ...,
#           [ 0.19381659,  0.08626255,  0.03430155,  0.09592756,
#             0.08660047],
#           [-0.09342897, -0.12267273, -0.37126976, -0.09040502,
#            -0.21844321],
#           [-0.1767197 , -0.24134094, -0.7804465 , -0.30034342,
#            -0.40039253]],
#
#          [[ 0.1759238 ,  0.28784952,  2.6717422 ,  0.13528994,
#             0.51311374],
#           [ 0.7536165 ,  0.67506915,  2.0546033 ,  0.60867167,
#             1.020723  ],
#           [ 0.4871592 ,  0.1547319 ,  0.5897145 ,  0.24838197,
#             0.5416727 ],
#           ...,
#           [ 0.20828457,  0.10011668, -0.0058479 ,  0.08342072,
#             0.06705032],
#           [-0.07617305, -0.09893103, -0.38832486, -0.08383311,
#            -0.21954075],
#           [-0.13604435, -0.21530345, -0.779593  , -0.27190396,
#            -0.3850753 ]]], dtype=float32),
#   'G': array([[[ 4.07648623e-01,  3.88981491e-01,  2.26901293e+00,
#             3.33032072e-01,  6.08293355e-01],
#           [ 9.92258430e-01,  1.34628558e+00,  2.53952909e+00,
#             1.19776714e+00,  1.35418952e+00],
#           [ 1.00682485e+00,  6.45377815e-01,  9.80843306e-01,
#             9.62440491e-01,  1.20544803e+00],
#           ...,
#           [ 2.20318899e-01,  1.19887002e-01,  2.44901776e-02,
#             1.55034870e-01,  2.35609025e-01],
#           [ 1.84801370e-02,  3.26801464e-02, -2.74779141e-01,
#             1.26442015e-02, -4.65433039e-02],
#           [-1.58787236e-01, -2.31373340e-01, -9.86221313e-01,
#            -3.94091815e-01, -5.16299427e-01]],
#
#          [[ 5.42098880e-01,  6.72164261e-01,  1.81523478e+00,
#             6.73672438e-01,  7.31911063e-01],
#           [ 1.45358908e+00,  2.72181535e+00,  3.03853440e+00,
#             2.60524011e+00,  2.04917312e+00],
#           [ 1.34290016e+00,  1.13221467e+00,  1.15584159e+00,
#           [ 2.07301569e+00,  3.13183403e+00,  4.08955145e+00,
#             3.33162427e+00,  2.72908854e+00],
#           [ 1.27347076e+00,  2.74443477e-01,  3.75367790e-01,
#             3.14244062e-01,  5.05740345e-01],
#           ...,
#           [ 7.87729144e-01,  5.21932244e-01,  3.43209863e-01,
#             5.29901028e-01,  4.62256610e-01],
#           [ 8.36340934e-02,  4.34299037e-02, -1.94567710e-01,
#             9.34459865e-02, -5.56230582e-02],
#           [-9.12354439e-02, -8.94266739e-03, -5.05662918e-01,
#            -6.57164305e-02, -1.73584759e-01]],
#
#          [[ 1.75767839e-01,  2.88205594e-01,  2.67179680e+00,
#             1.35440424e-01,  5.13319314e-01],
#           [ 7.53491521e-01,  6.75517857e-01,  2.05476213e+00,
#             6.09008551e-01,  1.02119529e+00],
#           [ 4.87022519e-01,  1.55104607e-01,  5.89689970e-01,
#             2.48576522e-01,  5.41914582e-01],
#           ...,
#           [ 7.47878492e-01,  4.68215495e-01,  2.77960926e-01,
#             4.85106945e-01,  4.26568210e-01],
#           [ 6.94830567e-02,  3.69288474e-02, -2.24705070e-01,
#             6.92541152e-02, -7.27086365e-02],
#           [-6.87081069e-02, -7.44406134e-03, -5.11675119e-01,
#            -6.03473559e-02, -1.76050872e-01]]], dtype=float32)}}

# %%
from random import sample
import json

# %%
f = open("/Users/ishanshah/Documents/covid-mrna-degradation/inference/results_dict_250.txt","w")
f.write( str(results_dict) )
f.close()
# View the effects of a randomly selected sequence
seq = sample(every_5_bases, 1)
output = 0
mean_effect = [0 for i in every_5_bases]
for ind, i in enumerate(every_5_bases):
    theta = 0
    for b in [3, 4, 5, 6]:
        theta = theta + results_dict[i][base_pairs[b]][seq][0][i][output]
    theta = theta / 4.0
    mean_effect[ind] = theta
# get original predictions
train_seq = train_inputs[seq,:,:]
train_seq_tens = torch.tensor(train_seq, dtype=torch.long)
train_seq_tens = train_seq_tens.clone().detach().requires_grad_(False)
model.eval()
preds = model(train_seq_tens, train_adj[seq,:,:])
preds = preds.cpu().detach().numpy()
# compute normalized effect
norm_effect = preds[0,:,output] - mean_effect
# plot effect
plt.plot(range(seq_len), norm_effect)
plt.ylabel('Normalized Effect')
plt.xlabel('Sequence Position')
plt.suptitle('Normalized Effect for Sequence ' + str(seq[0]))
plt.savefig('norm_effect_plot_' + str(seq[0]) + '.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-f97fe6a41484> in <module>()
#      20 preds = preds.cpu().detach().numpy()
#      21 # compute normalized effect
# ---> 22 norm_effect = preds[0,:,output] - mean_effect
#      23 # plot effect
#      24 plt.plot(range(seq_len), norm_effect)
#
# ValueError: operands could not be broadcast together with shapes (107,) (22,)

# %%
import pickle

# %%
with open('inference/results_dict_250.p', 'wb') as f:
    pickle.dump(results_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('inference/results_dict_250.p', 'rb') as fp:
    rd250 = pickle.load(fp)

# %%
a = np.array([[3,4,6,3], [4,6,6,3]])

# %%
[''.join(g) for g in (np.vectorize(base_pairs.get)(a))]
# Out:
# ['ACUA', 'CUUA']
